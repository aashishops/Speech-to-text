# %%
import os

# %%
def get_filenames_in_folder(folder_path):
    filenames = []
    for filename in os.listdir(folder_path):
        if os.path.isfile(os.path.join(folder_path, filename)):
            filenames.append(filename)
    return filenames

# %%
folder_path = r'E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos'
filenames = get_filenames_in_folder(folder_path)
print(filenames)
# Out:
# ['a lot.mp4', 'a.mp4', 'abdomen.mp4', 'able.mp4', 'about.mp4', 'above.mp4', 'accent.mp4', 'accept.mp4', 'accident.mp4', 'accomplish.mp4', 'accountant.mp4', 'across.mp4', 'act.mp4', 'action.mp4', 'active.mp4', 'activity.mp4', 'actor.mp4', 'adapt.mp4', 'add.mp4', 'address.mp4', 'adjective.mp4', 'adjust.mp4', 'admire.mp4', 'admit.mp4', 'adopt.mp4', 'adult.mp4', 'advanced.mp4', 'advantage.mp4', 'adverb.mp4', 'affect.mp4', 'afraid.mp4', 'africa.mp4', 'after.mp4', 'afternoon.mp4', 'again.mp4', 'against.mp4', 'age.mp4', 'agenda.mp4', 'ago.mp4', 'agree.mp4', 'agreement.mp4', 'ahead.mp4', 'aid.mp4', 'aim.mp4', 'airplane.mp4', 'alarm.mp4', 'alcohol.mp4', 'algebra.mp4', 'all day.mp4', 'all.mp4', 'allergy.mp4', 'alligator.mp4', 'allow.mp4', 'almost.mp4', 'alone.mp4', 'alphabet.mp4', 'already.mp4', 'also.mp4', 'always.mp4', 'amazing.mp4', 'america.mp4', 'amputate.mp4', 'analyze.mp4', 'anatomy.mp4', 'and.mp4', 'angel.mp4', 'angle.mp4', 'angry.mp4', 'animal.mp4', 'anniversary.mp4', 'announce.mp4', 
# ...

# %%
filenames = ['a lot.mp4', 'a.mp4', 'abdomen.mp4', 'able.mp4', 'about.mp4', 'above.mp4', 'accent.mp4', 'accept.mp4', 'accident.mp4', 'accomplish.mp4', 'accountant.mp4', 'across.mp4', 'act.mp4', 'action.mp4', 'active.mp4', 'activity.mp4', 'actor.mp4', 'adapt.mp4', 'add.mp4', 'address.mp4', 'adjective.mp4', 'adjust.mp4', 'admire.mp4', 'admit.mp4', 'adopt.mp4', 'adult.mp4', 'advanced.mp4', 'advantage.mp4', 'adverb.mp4', 'affect.mp4', 'afraid.mp4', 'africa.mp4', 'after.mp4', 'afternoon.mp4', 'again.mp4', 'against.mp4', 'age.mp4', 'agenda.mp4', 'ago.mp4', 'agree.mp4', 'agreement.mp4', 'ahead.mp4', 'aid.mp4', 'aim.mp4', 'airplane.mp4', 'alarm.mp4', 'alcohol.mp4', 'algebra.mp4', 'all day.mp4', 'all.mp4', 'allergy.mp4', 'alligator.mp4', 'allow.mp4', 'almost.mp4', 'alone.mp4', 'alphabet.mp4', 'already.mp4', 'also.mp4', 'always.mp4', 'amazing.mp4', 'america.mp4', 'amputate.mp4', 'analyze.mp4', 'anatomy.mp4', 'and.mp4', 'angel.mp4', 'angle.mp4', 'angry.mp4', 'animal.mp4', 'anniversary.mp4', 'announce.mp4', 'annoy.mp4', 'another.mp4', 'answer.mp4', 'any.mp4', 'anyway.mp4', 'apart.mp4', 'apartment.mp4', 'apostrophe.mp4', 'appear.mp4', 'appetite.mp4', 'apple.mp4', 'appointment.mp4', 'appreciate.mp4', 'approach.mp4', 'appropriate.mp4', 'approve.mp4', 'april.mp4', 'archery.mp4', 'area.mp4', 'argue.mp4', 'arizona.mp4', 'arm.mp4', 'army.mp4', 'around.mp4', 'arrest.mp4', 'arrive.mp4', 'arrogant.mp4', 'art.mp4', 'article.mp4', 'artist.mp4', 'asia.mp4', 'ask.mp4', 'asl.mp4', 'assist.mp4', 'assistant.mp4', 'assume.mp4', 'attend.mp4', 'attention.mp4', 'attitude.mp4', 'attorney.mp4', 'attract.mp4', 'auction.mp4', 'audience.mp4', 'audiologist.mp4', 'audiology.mp4', 'august.mp4', 'aunt.mp4', 'australia.mp4', 'austria.mp4', 'author.mp4', 'authority.mp4', 'autumn.mp4', 'available.mp4', 'average.mp4', 'avoid.mp4', 'awake.mp4', 'award.mp4', 'aware.mp4', 'away.mp4', 'awful.mp4', 'awkward.mp4', 'b.mp4', 'baby.mp4', 'babysitter.mp4', 'back.mp4', 'background.mp4', 'backpack.mp4', 'bacon.mp4', 'bad.mp4', 'bake.mp4', 'balance.mp4', 'bald.mp4', 'ball.mp4', 'balloon.mp4', 'banana.mp4', 'bank.mp4', 'baptize.mp4', 'bar.mp4', 'barely.mp4', 'bark.mp4', 'baseball.mp4', 'basement.mp4', 'basic.mp4', 'basketball.mp4', 'bath.mp4', 'bathroom.mp4', 'battery.mp4', 'battle.mp4', 'bear.mp4', 'beard.mp4', 'beautiful.mp4', 'because.mp4', 'become.mp4', 'bed.mp4', 'bedroom.mp4', 'bee.mp4', 'beer.mp4', 'before.mp4', 'beg.mp4', 'beginning.mp4', 'behavior.mp4', 'behind.mp4', 'belief.mp4', 'believe.mp4', 'bell.mp4', 'below.mp4', 'belt.mp4', 'benefit.mp4', 'berry.mp4', 'beside.mp4', 'best.mp4', 'bet.mp4', 'better.mp4', 'between.mp4', 'bible.mp4', 'bicycle.mp4', 'big.mp4', 'bike.mp4', 'binoculars.mp4', 'biology.mp4', 'bird.mp4', 'birth.mp4', 'birthday.mp4', 'bite.mp4', 'bitter.mp4', 'black.mp4', 'blame.mp4', 'blanket.mp4', 'blend.mp4', 'bless.mp4', 'blind.mp4', 'blood.mp4', 'blow.mp4', 'blue.mp4', 'boast.mp4', 'boat.mp4', 'body.mp4', 'boil.mp4', 'bone.mp4', 'book.mp4', 'bookshelf.mp4', 'bookstore.mp4', 'boots.mp4', 'bored.mp4', 'borrow.mp4', 'boss.mp4', 'both.mp4', 'bother.mp4', 'bottle.mp4', 'bottom.mp4', 'bowl.mp4', 'bowling.mp4', 'box.mp4', 'boxing.mp4', 'boy.mp4', 'boyfriend.mp4', 'bra.mp4', 'bracelet.mp4', 'brag.mp4', 'braid.mp4', 'brain.mp4', 'brave.mp4', 'bread.mp4', 'break.mp4', 'breakdown.mp4', 'breakfast.mp4', 'breathe.mp4', 'breeze.mp4', 'bribe.mp4', 'bridge.mp4', 'brief.mp4', 'bright.mp4', 'bring.mp4', 'brochure.mp4', 'broke.mp4', 'brother.mp4', 'brown.mp4', 'brush.mp4', 'buffalo.mp4', 'bug.mp4', 'build.mp4', 'building.mp4', 'bull.mp4', 'bully.mp4', 'burp.mp4', 'bus.mp4', 'bush.mp4', 'business.mp4', 'busy.mp4', 'but.mp4', 'butter.mp4', 'butterfly.mp4', 'button.mp4', 'buy.mp4', 'bye.mp4', 'cabbage.mp4', 'cabinet.mp4', 'cafeteria.mp4', 'cake.mp4', 'calculate.mp4', 'calculator.mp4', 'calculus.mp4', 'california.mp4', 'call.mp4', 'calm.mp4', 'camel.mp4', 'camera.mp4', 'camp.mp4', 'camping.mp4', 'can.mp4', 'canada.mp4', 'cancel.mp4', 'candidate.mp4', 'candle.mp4', 'candy.mp4', 'cannot.mp4', 'canoe.mp4', 'captain.mp4', 'caption.mp4', 'car.mp4', 'card.mp4', 'cards.mp4', 'care.mp4', 'careful.mp4', 'careless.mp4', 'carnival.mp4', 'carrot.mp4', 'carry.mp4', 'cat.mp4', 'catch.mp4', 'category.mp4', 'caterpillar.mp4', 'catholic.mp4', 'cause.mp4', 'ceiling.mp4', 'celebrate.mp4', 'cemetery.mp4', 'cent.mp4', 'center.mp4', 'cereal.mp4', 'certificate.mp4', 'chain.mp4', 'chair.mp4', 'challenge.mp4', 'champion.mp4', 'chance.mp4', 'change.mp4', 'chapter.mp4', 'character.mp4', 'chase.mp4', 'chat.mp4', 'cheap.mp4', 'cheat.mp4', 'check.mp4', 'cheerleader.mp4', 'cheese.mp4', 'chemical.mp4', 'chemistry.mp4', 'cherry.mp4', 'chicago.mp4', 'chicken.mp4', 'child.mp4', 'children.mp4', 'china.mp4', 'chocolate.mp4', 'choice.mp4', 'choir.mp4', 'choke.mp4', 'choose.mp4', 'chop.mp4', 'christ.mp4', 'christian.mp4', 'christmas.mp4', 'church.mp4', 'cigarette.mp4', 'circle.mp4', 'city.mp4', 'class.mp4', 'classroom.mp4', 'clean.mp4', 'clear.mp4', 'clever.mp4', 'click.mp4', 'climb.mp4', 'clock.mp4', 'close.mp4', 'closet.mp4', 'clothes.mp4', 'cloud.mp4', 'clown.mp4', 'clueless.mp4', 'clumsy.mp4', 'coach.mp4', 'coat.mp4', 'cochlear implant.mp4', 'coconut.mp4', 'coffee.mp4', 'cold.mp4', 'collect.mp4', 'college.mp4', 'color.mp4', 'comb.mp4', 'come here.mp4', 'come.mp4', 'comfortable.mp4', 'comma.mp4', 'command.mp4', 'comment.mp4', 'commit.mp4', 'committee.mp4', 'common sense.mp4', 'common.mp4', 'community.mp4', 'commute.mp4', 'company.mp4', 'compare.mp4', 'compete.mp4', 'complain.mp4', 'complete.mp4', 'complex.mp4', 'compromise.mp4', 'computer.mp4', 'concentrate.mp4', 'concept.mp4', 'concern.mp4', 'conflict.mp4', 'confront.mp4', 'confused.mp4', 'congratulations.mp4', 'congress.mp4', 'connect.mp4', 'conquer.mp4', 'consider.mp4', 'constitution.mp4', 'construct.mp4', 'consume.mp4', 'contact.mp4', 'contest.mp4', 'continue.mp4', 'contract.mp4', 'contribute.mp4', 'control.mp4', 'conversation.mp4', 'convert.mp4', 'convince.mp4', 'cook.mp4', 'cookie.mp4', 'cool.mp4', 'cooperate.mp4', 'cop.mp4', 'copy.mp4', 'corn.mp4', 'corner.mp4', 'correct.mp4', 'cost.mp4', 'couch.mp4', 'cough.mp4', 'counsel.mp4', 'counselor.mp4', 'count.mp4', 'country.mp4', 'court.mp4', 'cousin.mp4', 'cover.mp4', 'cow.mp4', 'crab.mp4', 'cracker.mp4', 'crash.mp4', 'crave.mp4', 'crazy.mp4', 'create.mp4', 'crocodile.mp4', 'cross.mp4', 'crown.mp4', 'cruel.mp4', 'crush.mp4', 'cry.mp4', 'cuba.mp4', 'culture.mp4', 'cup.mp4', 'curious.mp4', 'curriculum.mp4', 'curse.mp4', 'curtain.mp4', 'customer.mp4', 'cut.mp4', 'cute.mp4', 'd.mp4', 'dad.mp4', 'daily.mp4', 'damage.mp4', 'dance.mp4', 'dancer.mp4', 'danger.mp4', 'dangerous.mp4', 'dark.mp4', 'date.mp4', 'daughter.mp4', 'dawn.mp4', 'day.mp4', 'dead.mp4', 'deaf.mp4', 'death.mp4', 'debate.mp4', 'debt.mp4', 'december.mp4', 'decide.mp4', 'decorate.mp4', 'decrease.mp4', 'deduct.mp4', 'deep.mp4', 'deer.mp4', 'defeat.mp4', 'defend.mp4', 'degree.mp4', 'delay.mp4', 'delicious.mp4', 'deliver.mp4', 'demand.mp4', 'democrat.mp4', 'demonstrate.mp4', 'dentist.mp4', 'deny.mp4', 'deodorant.mp4', 'department.mp4', 'depend.mp4', 'deposit.mp4', 'depressed.mp4', 'descend.mp4', 'describe.mp4', 'desert.mp4', 'design.mp4', 'desk.mp4', 'dessert.mp4', 'destroy.mp4', 'detach.mp4', 'detective.mp4', 'determine.mp4', 'develop.mp4', 'devil.mp4', 'diabetes.mp4', 'diamond.mp4', 'diaper.mp4', 'diarrhea.mp4', 'dice.mp4', 'dictionary.mp4', 'die.mp4', 'different.mp4', 'difficult.mp4', 'dig.mp4', 'dime.mp4', 'dining room.mp4', 'dinner.mp4', 'dinosaur.mp4', 'diploma.mp4', 'director.mp4', 'dirt.mp4', 'dirty.mp4', 'disagree.mp4', 'disappear.mp4', 'discipline.mp4', 'disconnect.mp4', 'discount.mp4', 'discover.mp4', 'discuss.mp4', 'disgust.mp4', 'disgusted.mp4', 'dismiss.mp4', 'dissolve.mp4', 'disturb.mp4', 'dive.mp4', 'divide.mp4', 'division.mp4', 'divorce.mp4', 'dizzy.mp4', 'doctor.mp4', 'document.mp4', 'dog.mp4', 'doll.mp4', 'dollar.mp4', 'dolphin.mp4', "don't want.mp4", 'done.mp4', 'door.mp4', 'dorm.mp4', 'dormitory.mp4', 'double.mp4', 'doubt.mp4', 'down.mp4', 'downstairs.mp4', 'drag.mp4', 'dragon.mp4', 'drama.mp4', 'draw.mp4', 'drawer.mp4', 'dream.mp4', 'dress.mp4', 'drink.mp4', 'drive.mp4', 'drop.mp4', 'drug.mp4', 'drum.mp4', 'drunk.mp4', 'dry.mp4', 'duck.mp4', 'due.mp4', 'dull.mp4', 'dumb.mp4', 'during.mp4', 'dusk.mp4', 'duty.mp4', 'dvd.mp4', 'dye.mp4', 'e.mp4', 'each.mp4', 'eagle.mp4', 'ear.mp4', 'early.mp4', 'earn.mp4', 'earring.mp4', 'earth.mp4', 'earthquake.mp4', 'east.mp4', 'easter.mp4', 'easy.mp4', 'eat.mp4', 'economy.mp4', 'educate.mp4', 'education.mp4', 'effort.mp4', 'egg.mp4', 'egypt.mp4', 'eight.mp4', 'eighteen.mp4', 'either.mp4', 'electrician.mp4', 'electricity.mp4', 'elementary.mp4', 'elephant.mp4', 'elevator.mp4', 'else.mp4', 'email.mp4', 'embarrass.mp4', 'emergency.mp4', 'emotion.mp4', 'empty.mp4', 'encourage.mp4', 'end.mp4', 'energy.mp4', 'engage.mp4', 'engagement.mp4', 'engine.mp4', 'engineer.mp4', 'england.mp4', 'english.mp4', 'enjoy.mp4', 'enormous.mp4', 'enough.mp4', 'enter.mp4', 'envelope.mp4', 'environment.mp4', 'equal.mp4', 'erase.mp4', 'eraser.mp4', 'escape.mp4', 'establish.mp4', 'eternity.mp4', 'europe.mp4', 'evaluate.mp4', 'evening.mp4', 'event.mp4', 'every monday.mp4', 'every tuesday.mp4', 'every.mp4', 'everyday.mp4', 'everything.mp4', 'evidence.mp4', 'exact.mp4', 'exaggerate.mp4', 'example.mp4', 'except.mp4', 'exchange.mp4', 'excited.mp4', 'excuse.mp4', 'exercise.mp4', 'exhibit.mp4', 'expand.mp4', 'expect.mp4', 'expensive.mp4', 'experience.mp4', 'experiment.mp4', 'expert.mp4', 'explain.mp4', 'explode.mp4', 'express.mp4', 'eye.mp4', 'eyeglasses.mp4', 'eyes.mp4', 'f.mp4', 'face.mp4', 'fact.mp4', 'faculty.mp4', 'fail.mp4', 'fairy.mp4', 'fake.mp4', 'fall in love.mp4', 'familiar.mp4', 'family.mp4', 'famous.mp4', 'fancy.mp4', 'far.mp4', 'farm.mp4', 'farmer.mp4', 'fast.mp4', 'fat.mp4', 'father.mp4', 'fault.mp4', 'favorite.mp4', 'fear.mp4', 'february.mp4', 'federal.mp4', 'feed.mp4', 'feedback.mp4', 'feel.mp4', 'fence.mp4', 'festival.mp4', 'few.mp4', 'fight.mp4', 'final.mp4', 'finally.mp4', 'finance.mp4', 'find.mp4', 'fine.mp4', 'fingerspell.mp4', 'finish.mp4', 'fire.mp4', 'firefighter.mp4', 'first.mp4', 'fish.mp4', 'fishing.mp4', 'five.mp4', 'fix.mp4', 'flag.mp4', 'flatter.mp4', 'flexible.mp4', 'flirt.mp4', 'flood.mp4', 'floor.mp4', 'florida.mp4', 'flower.mp4', 'flute.mp4', 'fly.mp4', 'fold.mp4', 'follow.mp4', 'food.mp4', 'fool.mp4', 'football.mp4', 'for.mp4', 'forbid.mp4', 'forest.mp4', 'forever.mp4', 'forget.mp4', 'forgive.mp4', 'fork.mp4', 'form.mp4', 'former.mp4', 'four.mp4', 'fourth.mp4', 'fox.mp4', 'france.mp4', 'free.mp4', 'freeway.mp4', 'freeze.mp4', 'french fries.mp4', 'french.mp4', 'friday.mp4', 'friend.mp4', 'friendly.mp4', 'frog.mp4', 'from now on.mp4', 'from.mp4', 'front.mp4', 'fruit.mp4', 'full.mp4', 'fun.mp4', 'function.mp4', 'funeral.mp4', 'funny.mp4', 'furniture.mp4', 'future.mp4', 'g.mp4', 'gallaudet.mp4', 'gamble.mp4', 'game.mp4', 'gang.mp4', 'garage.mp4', 'gas.mp4', 'gasoline.mp4', 'gather.mp4', 'gay.mp4', 'general.mp4', 'generation.mp4', 'geography.mp4', 'geometry.mp4', 'german.mp4', 'germany.mp4', 'get up.mp4', 'get.mp4', 'ghost.mp4', 'gift.mp4', 'giraffe.mp4', 'girl.mp4', 'girlfriend.mp4', 'give up.mp4', 'give.mp4', 'glass.mp4', 'glasses.mp4', 'gloves.mp4', 'go.mp4', 'goal.mp4', 'goat.mp4', 'god.mp4', 'gold.mp4', 'golf.mp4', 'gone.mp4', 'good.mp4', 'goodbye.mp4', 'gorilla.mp4', 'gossip.mp4', 'government.mp4', 'grab.mp4', 'graduate.mp4', 'graduation.mp4', 'grammar.mp4', 'grandfather.mp4', 'grandma.mp4', 'grandmother.mp4', 'grapes.mp4', 'grass.mp4', 'grateful.mp4', 'gray.mp4', 'great.mp4', 'greece.mp4', 'green.mp4', 'grey.mp4', 'group.mp4', 'grow up.mp4', 'grow.mp4', 'guess.mp4', 'guide.mp4', 'guilty.mp4', 'guitar.mp4', 'gum.mp4', 'gun.mp4', 'gymnastics.mp4', 'h.mp4', 'habit.mp4', 'hair.mp4', 'haircut.mp4', 'half.mp4', 'halloween.mp4', 'hamburger.mp4', 'hammer.mp4', 'hang up.mp4', 'hanukkah.mp4', 'happen.mp4', 'happy.mp4', 'hard of hearing.mp4', 'hard.mp4', 'hat.mp4', 'hate.mp4', 'have.mp4', 'hawaii.mp4', 'head.mp4', 'headache.mp4', 'health.mp4', 'heap.mp4', 'hear.mp4', 'hearing aid.mp4', 'hearing.mp4', 'heart attack.mp4', 'heart.mp4', 'heaven.mp4', 'heavy.mp4', 'helicopter.mp4', 'hello.mp4', 'helmet.mp4', 'help.mp4', 'her.mp4', 'here.mp4', 'herself.mp4', 'hide.mp4', 'high school.mp4', 'high.mp4', 'highway.mp4', 'hill.mp4', 'hippopotamus.mp4', 'his.mp4', 'history.mp4', 'hit.mp4', 'hockey.mp4', 'hold.mp4', 'holy.mp4', 'home.mp4', 'homework.mp4', 'honest.mp4', 'honey.mp4', 'honor.mp4', 'hop.mp4', 'hope.mp4', 'horse.mp4', 'hospital.mp4', 'host.mp4', 'hot dog.mp4', 'hot.mp4', 'hour.mp4', 'house.mp4', 'how.mp4', 'hug.mp4', 'human.mp4', 'humble.mp4', 'hungry.mp4', 'hunt.mp4', 'hurricane.mp4', 'hurry.mp4', 'hurt.mp4', 'husband.mp4', 'i.mp4', 'ice cream.mp4', 'idea.mp4', 'identify.mp4', 'if.mp4', 'ignore.mp4', 'ill.mp4', 'illegal.mp4', 'image.mp4', 'impact.mp4', 'important.mp4', 'impossible.mp4', 'improve.mp4', 'in.mp4', 'include.mp4', 'increase.mp4', 'independent.mp4', 'india.mp4', 'individual.mp4', 'infection.mp4', 'influence.mp4', 'inform.mp4', 'information.mp4', 'innocent.mp4', 'insect.mp4', 'inside.mp4', 'inspect.mp4', 'inspire.mp4', 'instead.mp4', 'institute.mp4', 'insurance.mp4', 'interest.mp4', 'interesting.mp4', 'international.mp4', 'internet.mp4', 'interpret.mp4', 'interpreter.mp4', 'interrupt.mp4', 'intersection.mp4', 'interview.mp4', 'introduce.mp4', 'invest.mp4', 'investigate.mp4', 'invite.mp4', 'involve.mp4', 'iran.mp4', 'ireland.mp4', 'iron.mp4', 'island.mp4', 'israel.mp4', 'italy.mp4', 'j.mp4', 'jacket.mp4', 'jail.mp4', 'january.mp4', 'japan.mp4', 'jealous.mp4', 'jesus.mp4', 'jewelry.mp4', 'jewish.mp4', 'join.mp4', 'joke.mp4', 'journey.mp4', 'joy.mp4', 'judge.mp4', 'july.mp4', 'jump.mp4', 'june.mp4', 'k.mp4', 'kangaroo.mp4', 'karate.mp4', 'keep.mp4', 'key.mp4', 'keyboard.mp4', 'kick.mp4', 'kid.mp4', 'kill.mp4', 'kindergarten.mp4', 'king.mp4', 'kiss.mp4', 'kitchen.mp4', 'kneel.mp4', 'knife.mp4', 'knock.mp4', 'know.mp4', 'label.mp4', 'lady.mp4', 'lamp.mp4', 'land.mp4', 'language.mp4', 'laptop.mp4', 'large.mp4', 'last week.mp4', 'last year.mp4', 'last.mp4', 'late.mp4', 'later.mp4', 'laugh.mp4', 'laundry.mp4', 'law.mp4', 'lawyer.mp4', 'lazy.mp4', 'lead.mp4', 'leader.mp4', 'leaf.mp4', 'league.mp4', 'leak.mp4', 'leave.mp4', 'lecture.mp4', 'left.mp4', 'legal.mp4', 'lemon.mp4', 'lend.mp4', 'lesbian.mp4', 'less.mp4', 'lesson.mp4', 'let.mp4', 'letter.mp4', 'lettuce.mp4', 'liability.mp4', 'librarian.mp4', 'library.mp4', 'license.mp4', 'lie.mp4', 'lift.mp4', 'light.mp4', 'lightning.mp4', 'like.mp4', 'limit.mp4', 'line.mp4', 'linguistics.mp4', 'lion.mp4', 'lip.mp4', 'lipstick.mp4', 'list.mp4', 'listen.mp4', 'little bit.mp4', 'live.mp4', 'loan.mp4', 'lobster.mp4', 'local.mp4', 'lock.mp4', 'lonely.mp4', 'long.mp4', 'look at.mp4', 'look for.mp4', 'lord.mp4', 'lose.mp4', 'loud.mp4', 'lousy.mp4', 'love.mp4', 'lucky.mp4', 'lunch.mp4', 'm.mp4', 'machine.mp4', 'mad.mp4', 'magazine.mp4', 'magic.mp4', 'mainstream.mp4', 'major.mp4', 'make.mp4', 'man.mp4', 'manage.mp4', 'manager.mp4', 'many.mp4', 'march.mp4', 'marry.mp4', 'match.mp4', 'math.mp4', 'mature.mp4', 'maximum.mp4', 'maybe.mp4', 'me.mp4', 'mean.mp4', 'meaning.mp4', 'measure.mp4', 'meat.mp4', 'mechanic.mp4', 'medicine.mp4', 'meet.mp4', 'meeting.mp4', 'melody.mp4', 'melt.mp4', 'member.mp4', 'memorize.mp4', 'mention.mp4', 'message.mp4', 'metal.mp4', 'mexico.mp4', 'microphone.mp4', 'microscope.mp4', 'microwave.mp4', 'middle.mp4', 'midnight.mp4', 'military.mp4', 'milk.mp4', 'mind.mp4', 'mine.mp4', 'minus.mp4', 'minute.mp4', 'mirror.mp4', 'miss.mp4', 'mistake.mp4', 'misunderstand.mp4', 'mix.mp4', 'mock.mp4', 'mom.mp4', 'monday.mp4', 'money.mp4', 'monkey.mp4', 'monster.mp4', 'month.mp4', 'monthly.mp4', 'moon.mp4', 'moose.mp4', 'more.mp4', 'morning.mp4', 'mosquito.mp4', 'most.mp4', 'mother.mp4', 'motivate.mp4', 'motor.mp4', 'motorcycle.mp4', 'mountain.mp4', 'mouse.mp4', 'mouth.mp4', 'move.mp4', 'much.mp4', 'multiply.mp4', 'murder.mp4', 'muscle.mp4', 'museum.mp4', 'mushroom.mp4', 'music.mp4', 'must.mp4', 'mustache.mp4', 'my.mp4', 'myself.mp4', 'n.mp4', 'name.mp4', 'napkin.mp4', 'narrow.mp4', 'nation.mp4', 'near.mp4', 'necessary.mp4', 'neck.mp4', 'necklace.mp4', 'need.mp4', 'negative.mp4', 'negotiate.mp4', 'neighbor.mp4', 'nephew.mp4', 'nervous.mp4', 'network.mp4', 'neutral.mp4', 'never.mp4', 'new york.mp4', 'new.mp4', 'newspaper.mp4', 'next.mp4', 'nice.mp4', 'nickel.mp4', 'niece.mp4', 'night.mp4', 'nine.mp4', 'nineteen.mp4', 'no.mp4', 'none.mp4', 'noon.mp4', 'normal.mp4', 'north.mp4', 'northwest.mp4', 'nose.mp4', 'not yet.mp4', 'not.mp4', 'nothing.mp4', 'notice.mp4', 'november.mp4', 'now.mp4', 'number.mp4', 'numerous.mp4', 'nun.mp4', 'nurse.mp4', 'nut.mp4', 'o.mp4', 'objective.mp4', 'obsess.mp4', 'obtain.mp4', 'occur.mp4', 'ocean.mp4', 'october.mp4', 'octopus.mp4', 'odd.mp4', 'odor.mp4', 'off.mp4', 'offer.mp4', 'office.mp4', 'often.mp4', 'ok.mp4', 'old.mp4', 'olympics.mp4', 'on.mp4', 'once.mp4', 'one.mp4', 'onion.mp4', 'only.mp4', 'open.mp4', 'operate.mp4', 'opinion.mp4', 'opposite.mp4', 'or.mp4', 'oral.mp4', 'orange.mp4', 'order.mp4', 'organize.mp4', 'other.mp4', 'our.mp4', 'out.mp4', 'outside.mp4', 'over.mp4', 'overcome.mp4', 'overlook.mp4', 'overwhelm.mp4', 'owe.mp4', 'owl.mp4', 'p.mp4', 'pack.mp4', 'page.mp4', 'pain.mp4', 'paint.mp4', 'painter.mp4', 'pants.mp4', 'paper.mp4', 'parachute.mp4', 'parade.mp4', 'paragraph.mp4', 'parallel.mp4', 'parents.mp4', 'part.mp4', 'party.mp4', 'pass.mp4', 'past.mp4', 'path.mp4', 'patient.mp4', 'pause.mp4', 'pay attention.mp4', 'pay.mp4', 'peace.mp4', 'peaceful.mp4', 'peach.mp4', 'peanut butter.mp4', 'pear.mp4', 'peel.mp4', 'penalty.mp4', 'pencil.mp4', 'pennsylvania.mp4', 'penny.mp4', 'people.mp4', 'pepper.mp4', 'percent.mp4', 'perfect.mp4', 'perfume.mp4', 'period.mp4', 'permit.mp4', 'person.mp4', 'personality.mp4', 'perspective.mp4', 'pet.mp4', 'philadelphia.mp4', 'philosophy.mp4', 'phone.mp4', 'photographer.mp4', 'phrase.mp4', 'physician.mp4', 'physics.mp4', 'piano.mp4', 'pick.mp4', 'pickle.mp4', 'picture.mp4', 'pie.mp4', 'piece.mp4', 'pig.mp4', 'pillow.mp4', 'pilot.mp4', 'pink.mp4', 'pity.mp4', 'pizza.mp4', 'place.mp4', 'plan.mp4', 'plant.mp4', 'plate.mp4', 'play.mp4', 'player.mp4', 'please.mp4', 'plenty.mp4', 'plus.mp4', 'pneumonia.mp4', 'pocket.mp4', 'point.mp4', 'polar bear.mp4', 'police.mp4', 'policeman.mp4', 'policy.mp4', 'polite.mp4', 'politics.mp4', 'poop.mp4', 'poor.mp4', 'popcorn.mp4', 'popular.mp4', 'position.mp4', 'positive.mp4', 'possible.mp4', 'post.mp4', 'postpone.mp4', 'potato.mp4', 'potential.mp4', 'pound.mp4', 'pour.mp4', 'poverty.mp4', 'power.mp4', 'practice.mp4', 'praise.mp4', 'pray.mp4', 'preach.mp4', 'preacher.mp4', 'precious.mp4', 'precipitation.mp4', 'precise.mp4', 'predict.mp4', 'prefer.mp4', 'pregnant.mp4', 'prepare.mp4', 'preschool.mp4', 'present.mp4', 'presentation.mp4', 'president.mp4', 'pressure.mp4', 'pretty.mp4', 'prevent.mp4', 'price.mp4', 'pride.mp4', 'priest.mp4', 'prince.mp4', 'princess.mp4', 'principal.mp4', 'principle.mp4', 'print.mp4', 'printer.mp4', 'priority.mp4', 'prison.mp4', 'private.mp4', 'problem.mp4', 'process.mp4', 'procrastinate.mp4', 'professional.mp4', 'professor.mp4', 'profit.mp4', 'program.mp4', 'progress.mp4', 'project.mp4', 'promise.mp4', 'promote.mp4', 'proof.mp4', 'propaganda.mp4', 'proper.mp4', 'prostitute.mp4', 'protect.mp4', 'proud.mp4', 'prove.mp4', 'provide.mp4', 'psychologist.mp4', 'psychology.mp4', 'public.mp4', 'publish.mp4', 'pull.mp4', 'pumpkin.mp4', 'punish.mp4', 'purchase.mp4', 'pure.mp4', 'purple.mp4', 'purpose.mp4', 'pursue.mp4', 'push.mp4', 'put off.mp4', 'put.mp4', 'puzzled.mp4', 'q.mp4', 'quality.mp4', 'quarrel.mp4', 'quarter.mp4', 'queen.mp4', 'question.mp4', 'quick.mp4', 'quiet.mp4', 'quit.mp4', 'quote.mp4', 'r.mp4', 'raccoon.mp4', 'race.mp4', 'radio.mp4', 'rage.mp4', 'rain.mp4', 'rainbow.mp4', 'rake.mp4', 'rat.mp4', 'rather.mp4', 'ready.mp4', 'real.mp4', 'realize.mp4', 'really.mp4', 'reason.mp4', 'receive.mp4', 'recent.mp4', 'recliner.mp4', 'recognize.mp4', 'recommend.mp4', 'recover.mp4', 'reduce.mp4', 'refer.mp4', 'referee.mp4', 'refuse.mp4', 'regular.mp4', 'rehearse.mp4', 'reject.mp4', 'relate.mp4', 'relationship.mp4', 'relax.mp4', 'release.mp4', 'relief.mp4', 'religion.mp4', 'rely.mp4', 'remember.mp4', 'remote control.mp4', 'remove.mp4', 'rent.mp4', 'repeat.mp4', 'replace.mp4', 'reply.mp4', 'report.mp4', 'represent.mp4', 'reputation.mp4', 'request.mp4', 'require.mp4', 'rescue.mp4', 'research.mp4', 'resign.mp4', 'resist.mp4', 'respect.mp4', 'responsibility.mp4', 'responsible.mp4', 'rest.mp4', 'restaurant.mp4', 'restroom.mp4', 'result.mp4', 'retire.mp4', 'retreat.mp4', 'reveal.mp4', 'revenge.mp4', 'review.mp4', 'rich.mp4', 'ride.mp4', 'ridiculous.mp4', 'right.mp4', 'ring.mp4', 'rise.mp4', 'river.mp4', 'road.mp4', 'roar.mp4', 'rob.mp4', 'robber.mp4', 'robot.mp4', 'rock.mp4', 'role.mp4', 'roof.mp4', 'roommate.mp4', 'rooster.mp4', 'rope.mp4', 'rose.mp4', 'rough.mp4', 'rubber.mp4', 'rude.mp4', 'ruin.mp4', 'rule.mp4', 'rush.mp4', 'russia.mp4', 's.mp4', 'sad.mp4', 'safe.mp4', 'salad.mp4', 'salary.mp4', 'salt.mp4', 'salute.mp4', 'same.mp4', 'sandwich.mp4', 'satisfy.mp4', 'saturday.mp4', 'sauce.mp4', 'sausage.mp4', 'save.mp4', 'saw.mp4', 'say.mp4', 'scan.mp4', 'scared.mp4', 'schedule.mp4', 'school.mp4', 'science.mp4', 'scientist.mp4', 'scissors.mp4', 'scold.mp4', 'score.mp4', 'scotland.mp4', 'scream.mp4', 'screwdriver.mp4', 'sculpture.mp4', 'sea.mp4', 'search.mp4', 'second.mp4', 'secret.mp4', 'secretary.mp4', 'see.mp4', 'seem.mp4', 'seldom.mp4', 'selfish.mp4', 'sell.mp4', 'senate.mp4', 'send.mp4', 'senior.mp4', 'sensitive.mp4', 'sentence.mp4', 'separate.mp4', 'september.mp4', 'sequence.mp4', 'serious.mp4', 'serve.mp4', 'service.mp4', 'settle.mp4', 'seven.mp4', 'several.mp4', 'sew.mp4', 'shame.mp4', 'shampoo.mp4', 'shape.mp4', 'share.mp4', 'shave.mp4', 'she.mp4', 'sheep.mp4', 'shelf.mp4', 'shine.mp4', 'shirt.mp4', 'shock.mp4', 'shoes.mp4', 'shoot.mp4', 'shop.mp4', 'shopping.mp4', 'short.mp4', 'should.mp4', 'shoulder.mp4', 'shout.mp4', 'shovel.mp4', 'shower.mp4', 'shrimp.mp4', 'shy.mp4', 'sick.mp4', 'side.mp4', 'sign language.mp4', 'sign.mp4', 'silent.mp4', 'silly.mp4', 'silver.mp4', 'similar.mp4', 'simple.mp4', 'sin.mp4', 'since.mp4', 'sing.mp4', 'singer.mp4', 'single.mp4', 'siren.mp4', 'sister.mp4', 'sit.mp4', 'situation.mp4', 'six.mp4', 'sixteen.mp4', 'size.mp4', 'skate.mp4', 'skeleton.mp4', 'sketch.mp4', 'ski.mp4', 'skill.mp4', 'skin.mp4', 'skinny.mp4', 'skip.mp4', 'skirt.mp4', 'skunk.mp4', 'sky.mp4', 'slave.mp4', 'sleep.mp4', 'sleepy.mp4', 'slice.mp4', 'slip.mp4', 'slow.mp4', 'small.mp4', 'smart.mp4', 'smell.mp4', 'smile.mp4', 'smoking.mp4', 'smooth.mp4', 'snack.mp4', 'snake.mp4', 'sneeze.mp4', 'snob.mp4', 'snow.mp4', 'snowman.mp4', 'soap.mp4', 'soccer.mp4', 'society.mp4', 'socks.mp4', 'soda.mp4', 'sofa.mp4', 'soft.mp4', 'soldier.mp4', 'solid.mp4', 'solve.mp4', 'some.mp4', 'someday.mp4', 'someone.mp4', 'something.mp4', 'sometimes.mp4', 'somewhere.mp4', 'son.mp4', 'song.mp4', 'soon.mp4', 'sore throat.mp4', 'sorry.mp4', 'soul.mp4', 'sound.mp4', 'soup.mp4', 'sour.mp4', 'south america.mp4', 'south.mp4', 'spain.mp4', 'spanish.mp4', 'speak.mp4', 'special.mp4', 'specific.mp4', 'speech.mp4', 'speed.mp4', 'spell.mp4', 'spider.mp4', 'spill.mp4', 'spin.mp4', 'spirit.mp4', 'spit.mp4', 'spoon.mp4', 'spray.mp4', 'spread.mp4', 'spring.mp4', 'sprint.mp4', 'square.mp4', 'squeeze.mp4', 'squirrel.mp4', 'stadium.mp4', 'staff.mp4', 'stairs.mp4', 'stamp.mp4', 'stand.mp4', 'standard.mp4', 'star.mp4', 'stare.mp4', 'start.mp4', 'statistics.mp4', 'stay.mp4', 'steal.mp4', 'steel.mp4', 'stepfather.mp4', 'sticky.mp4', 'still.mp4', 'sting.mp4', 'stink.mp4', 'stir.mp4', 'stitch.mp4', 'stomach.mp4', 'stop.mp4', 'store.mp4', 'story.mp4', 'straight.mp4', 'strange.mp4', 'straw.mp4', 'strawberry.mp4', 'street.mp4', 'stress.mp4', 'stretch.mp4', 'strict.mp4', 'strong.mp4', 'structure.mp4', 'struggle.mp4', 'stubborn.mp4', 'stuck.mp4', 'student.mp4', 'study.mp4', 'stupid.mp4', 'subtract.mp4', 'subway.mp4', 'sue.mp4', 'suffer.mp4', 'sugar.mp4', 'suggest.mp4', 'summer.mp4', 'summon.mp4', 'sun.mp4', 'sunday.mp4', 'sunrise.mp4', 'sunset.mp4', 'sunshine.mp4', 'superman.mp4', 'support.mp4', 'suppose.mp4', 'sure.mp4', 'surface.mp4', 'surgeon.mp4', 'surgery.mp4', 'surprise.mp4', 'surrender.mp4', 'suspect.mp4', 'suspend.mp4', 'swallow.mp4', 'sweater.mp4', 'sweden.mp4', 'sweep.mp4', 'sweet.mp4', 'sweetheart.mp4', 'swim.mp4', 'swimming.mp4', 'swimsuit.mp4', 'swing.mp4', 'switzerland.mp4', 'symbol.mp4', 'sympathy.mp4', 't.mp4', 'table.mp4', 'take turns.mp4', 'take up.mp4', 'take.mp4', 'tale.mp4', 'talent.mp4', 'talk.mp4', 'tall.mp4', 'tan.mp4', 'taste.mp4', 'tea.mp4', 'teach.mp4', 'teacher.mp4', 'team.mp4', 'tease.mp4', 'technology.mp4', 'teeth.mp4', 'telephone.mp4', 'telescope.mp4', 'television.mp4', 'tell.mp4', 'temperature.mp4', 'temple.mp4', 'tempt.mp4', 'ten.mp4', 'tend.mp4', 'tender.mp4', 'tennis.mp4', 'tent.mp4', 'terrible.mp4', 'test.mp4', 'testify.mp4', 'texas.mp4', 'text.mp4', 'thailand.mp4', 'than.mp4', 'thank you.mp4', 'thankful.mp4', 'thanksgiving.mp4', 'that.mp4', 'theater.mp4', 'their.mp4', 'them.mp4', 'theme.mp4', 'themselves.mp4', 'then.mp4', 'theory.mp4', 'therapy.mp4', 'there.mp4', 'therefore.mp4', 'thermometer.mp4', 'they.mp4', 'thick.mp4', 'thin.mp4', 'thing.mp4', 'think.mp4', 'third.mp4', 'thirsty.mp4', 'this.mp4', 'thousand.mp4', 'three.mp4', 'thrill.mp4', 'throat.mp4', 'through.mp4', 'throw.mp4', 'thursday.mp4', 'ticket.mp4', 'tie.mp4', 'tiger.mp4', 'time.mp4', 'tiptoe.mp4', 'tired.mp4', 'tissue.mp4', 'title.mp4', 'to.mp4', 'toast.mp4', 'tobacco.mp4', 'today.mp4', 'together.mp4', 'toilet paper.mp4', 'toilet.mp4', 'tolerate.mp4', 'tomato.mp4', 'tomorrow.mp4', 'tongue.mp4', 'tonight.mp4', 'tooth.mp4', 'toothbrush.mp4', 'top.mp4', 'topic.mp4', 'tornado.mp4', 'torture.mp4', 'total.mp4', 'touch.mp4', 'tough.mp4', 'tournament.mp4', 'towel.mp4', 'tower.mp4', 'town.mp4', 'trade.mp4', 'tradition.mp4', 'traffic.mp4', 'train.mp4', 'tranquil.mp4', 'transfer.mp4', 'transform.mp4', 'translate.mp4', 'travel.mp4', 'tree.mp4', 'triangle.mp4', 'trip.mp4', 'trophy.mp4', 'trouble.mp4', 'truck.mp4', 'true.mp4', 'trust.mp4', 'truth.mp4', 'try.mp4', 'tuesday.mp4', 'turkey.mp4', 'turn.mp4', 'turtle.mp4', 'tutor.mp4', 'tv.mp4', 'twin.mp4', 'two.mp4', 'type.mp4', 'u.mp4', 'ugly.mp4', 'umbrella.mp4', 'uncle.mp4', 'under.mp4', 'understand.mp4', 'underwear.mp4', 'unique.mp4', 'united states.mp4', 'university.mp4', 'until.mp4', 'up.mp4', 'upset.mp4', 'upstairs.mp4', 'use.mp4', 'v.mp4', 'vacant.mp4', 'vacation.mp4', 'vague.mp4', 'valley.mp4', 'value.mp4', 'vampire.mp4', 'vegetable.mp4', 'verb.mp4', 'very.mp4', 'vice president.mp4', 'viewpoint.mp4', 'violin.mp4', 'visit.mp4', 'visitor.mp4', 'visualize.mp4', 'vlog.mp4', 'vocabulary.mp4', 'voice.mp4', 'volleyball.mp4', 'volunteer.mp4', 'vomit.mp4', 'vote.mp4', 'w.mp4', 'wait.mp4', 'waiter.mp4', 'wake up.mp4', 'walk.mp4', 'wall.mp4', 'wallet.mp4', 'wander.mp4', 'want.mp4', 'war.mp4', 'warm.mp4', 'warn.mp4', 'wash face.mp4', 'wash.mp4', 'washington.mp4', 'waste.mp4', 'watch.mp4', 'water.mp4', 'waterfall.mp4', 'watermelon.mp4', 'way.mp4', 'we.mp4', 'weak.mp4', 'wear.mp4', 'weather.mp4', 'wedding.mp4', 'wednesday.mp4', 'week.mp4', 'weekend.mp4', 'weekly.mp4', 'weigh.mp4', 'weight.mp4', 'weird.mp4', 'welcome.mp4', 'west.mp4', 'wet.mp4', 'whale.mp4', 'what.mp4', 'whatever.mp4', 'wheelchair.mp4', 'when.mp4', 'where.mp4', 'which.mp4', 'while.mp4', 'whistle.mp4', 'white.mp4', 'who.mp4', 'why.mp4', 'wide.mp4', 'wife.mp4', 'will.mp4', 'willing.mp4', 'win.mp4', 'wind.mp4', 'window.mp4', 'wine.mp4', 'winter.mp4', 'wish.mp4', 'with.mp4', 'within.mp4', 'without.mp4', 'witness.mp4', 'wolf.mp4', 'woman.mp4', 'wonder.mp4', 'wonderful.mp4', 'wood.mp4', 'word.mp4', 'work.mp4', 'worker.mp4', 'workshop.mp4', 'world.mp4', 'worm.mp4', 'worry.mp4', 'worse.mp4', 'worthless.mp4', 'wow.mp4', 'wrap.mp4', 'wrench.mp4', 'wristwatch.mp4', 'write.mp4', 'wrong.mp4', 'year.mp4', 'yellow.mp4', 'yes.mp4', 'yesterday.mp4', 'you.mp4', 'young.mp4', 'your.mp4', 'yourself.mp4', 'zero.mp4']

# %%
words = {}
for filename in filenames:  
    word = filename[:-4]
    words[word] = r"E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\"+filename

# %%
print("Dictionary of Filenames:")
for key, value in words.items():
    print(key, ":", value)
# Out:
# Dictionary of Filenames:
# a lot : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\a lot.mp4
# a : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\a.mp4
# abdomen : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\abdomen.mp4
# able : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\able.mp4
# about : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\about.mp4
# above : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\above.mp4
# accent : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\accent.mp4
# accept : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\accept.mp4
# accident : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\accident.mp4
# accomplish : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\accomplish.mp4
# accountant : E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\accountant.mp4
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\aashi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aashi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\aashi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aashi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from playsound import playsound

# %%
def text_to_sign(text, sign_dict):
    # Tokenization
    tokens = word_tokenize(text)

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]

    # Find corresponding sign language videos
    for lemma in lemmas:

        video_path = sign_dict.get(lemma)
        print(video_path)


# Test the function
text_to_sign('hello how are you', words)
# Out:
# E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\hello.mp4
# E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\how.mp4
# None
# E:\College\2nd year\hackathon\Mozohack\backend\data\raw_videos\\you.mp4

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

def text_to_sign(text, sign_dict):
    # Tokenization
    tokens = word_tokenize(text)

    # Lemmatization with POS tagging
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(token, get_wordnet_pos(token)) for token in tokens]

    # Find corresponding sign language videos
    for lemma in lemmas:
        video_path = sign_dict.get(lemma)
        if video_path:
            print(video_path)
        else:
            print(f"No sign found for {lemma}")

# Test the function
text_to_sign('im so powerful', words)
# Out:
# No sign found for im
# No sign found for so
# No sign found for powerful
